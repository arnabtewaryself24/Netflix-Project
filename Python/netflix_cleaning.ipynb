# %%
import pandas as pd
import numpy as np

df = pd.read_excel("../Data/Raw/Netflix TV Shows and Movies.xlsx")

df.head()
df.info()
df.shape
df.isnull().sum()

df = df.drop_duplicates()

print(df.shape)

df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)

df.columns

df["description"] = df["description"].fillna("No Description Available")
df["age_certification"] = (df["age_certification"].fillna("Unknown"))

median_votes = df["imdb_votes"].median()

df["imdb_votes"] = (df["imdb_votes"].fillna(median_votes))

df.isnull().sum()

df["runtime"] = pd.to_numeric(
    df["runtime"],
    errors="coerce"
)

df["runtime"] = (
    df["runtime"]
      .fillna(df["runtime"].median())
)

df["runtime"].describe()

df["release_year"] = pd.to_numeric(
    df["release_year"],
    errors="coerce"
)

df["release_year"] = (
    df["release_year"]
      .fillna(df["release_year"].median())
      .astype(int)
)
df.info()

df["type"].value_counts()
df["imdb_score"].describe()

df.to_csv(
    "../Data/Cleaned/netflix_cleaned.csv",
    index=False
)

print("Cleaned dataset saved successfully!")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   str
#  2   title              5283 non-null   object
#  3   type               5283 non-null   str
#  4   description        5278 non-null   str
#  5   release_year       5283 non-null   int64
#  6   age_certification  2998 non-null   str
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   str
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5267 non-null   float64
# dtypes: float64(2), int64(3), object(1), str(5)
# memory usage: 454.1+ KB
# (5283, 11)
# <class 'pandas.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ...
